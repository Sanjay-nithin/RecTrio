# %% [markdown]
# # CLIP-based Image Similarity Training Pipeline
# ## Complete Training Notebook for Google Colab
#
# This notebook implements a two-phase triplet learning approach using CLIP:
# - **Phase 1**: Train projection head (CLIP frozen)
# - **Phase 2**: Fine-tune CLIP layers + projection head
#
# ### Features:
# - Automatic dataset discovery from folder structure
# - CLIP-based feature extraction
# - Triplet loss with margin
# - Learning rate scheduling
# - Early stopping
# - Model checkpointing
# - Training visualization

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Setup: Install Dependencies

# %%
# Install required packages
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install ftfy regex tqdm
# !pip install git+https://github.com/openai/CLIP.git
# !pip install Pillow numpy matplotlib seaborn pandas scikit-learn
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.9.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.24.0+cu126)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (2.9.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Collecting ftfy
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy) (0.2.14)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: ftfy
# Successfully installed ftfy-6.3.1
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-lid0qkgt
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-lid0qkgt
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ftfy in /usr/local/lib/python3.12/dist-packages (from clip==1.0) (6.3.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from clip==1.0) (25.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from clip==1.0) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from clip==1.0) (4.67.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from clip==1.0) (2.9.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from clip==1.0) (0.24.0+cu126)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy->clip==1.0) (0.2.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (3.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision->clip==1.0) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->clip==1.0) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->clip==1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->clip==1.0) (3.0.3)
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369490 sha256=acea49e3d1240f70bd6d95006ce73f60ad2c27152ed13c59bf8d81823fc8cd32
#   Stored in directory: /tmp/pip-ephem-wheel-cache-s96berac/wheels/35/3e/df/3d24cbfb3b6a06f17a2bfd7d1138900d4365d9028aa8f6e92f
# Successfully built clip
# Installing collected packages: clip
# Successfully installed clip-1.0
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# !unzip "/content/drive/MyDrive/raw-img.zip" -d "/content/drive/MyDrive/raw-img"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eBblY9bQyUrRADbLuh7pMQHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-Ebel8CWMjbPSxpiQs-hAKwHaFi.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EbErR8KNlYyBM9jlNrIGIAHaGK.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eBN9F0r9OL4COmgyEYGvaAEVEs.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EbpsFIp42kQg7B467MR5bQHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-ecbjPxEXH_UreyOy1xjZlQHaFH.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EcBwehwooCBORsmW1hDq6gHaGm.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-ECg-But0WowvNZcIb8QIeAHaEo.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EcIZuLV7tnHDYHDPO0wVdAHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-ECk9akfPinT4wzOOcsYOqgHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EckToZ388WVMmxwQ8UlndgHaEK.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-ecrlgjnUaHSlYUtyPmN5wwHaFS.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EcxdFy8-9UBZGwjSnNtTKAHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eD2xyPHtfhO7QtWTKRN1xwHaFk.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eDDQfz6fqNOKiz4KtUlfqQHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-edMmYc1icp_B6nrPzsHm3wHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eEGW4vQfQSTXdlF1nrZ97wHaGN.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EeK8qer_ndgujpo---RUYAHaKU.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eEWA1YRTeHTQ5XFZjN-zrQHaIO.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eEzMveRElX21u0OCZEq3cAEsDh.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EFHHEtcDjm_Vasbe0vI63gHaHa.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EGAVUqFTkSOSMYHDJBKfOAHaGw.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EGDKBzxqlloW1IoFSDvNogEsEP.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-egeat4QiFVFxtWY2sVOOsgHaFV.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EGgi4CdQu-UeUOuZP946agHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EGoEdrizg77VfTR_puk8pQHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-egR2Ww679tybsL4kBrm1qQHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eGUMsoPBylkIFq_kW0vS1wHaFF.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eGV6kFvYhoEGRU4xuq9oIQHaFd.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eH2QMeJh2VrFkSGFBfxQNQEsEn.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eh8eD8Sy2vBthG_wh0XA-wHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eHS3yPBn4lxdh_j8SAoIGwHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eI2L6NJiXOTmnKxBowZ6JADHEs.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-ei4X-ln_qYRw3yBkFpEjfwHaE6.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-ein1frrZTNwDUZisFNczUwHaE1.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EIx8WI_hmZ1NaXKPbp3BLAHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EiXDM0-84JJMsJwR6UyqqAHaHa.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-ejefvxLR5SxKTvhbInlULwHaGd.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EjhU2mEsuFMD_9fR3K_SCgHaGA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eJhXHaqrc0d_V9UjXCYMlwHaF8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-Ejr-WL3ngIDbdkJRsU7D8wHaED.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eJrfB-vuv07hR2-UTzD_FgHaHa.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eJSR-7IGlwP_-GJYXLuhnAHaFr.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EJY-TM9GEi2p1UxpcKhDJQHaHS.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EK7hGWYAxZcdFJUsnj4KeAHaJk.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-ekEb1nBPKimS2BdASy1yYAEsEs.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EKGmL1a5jKNv5MalC1CU6QHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EkM6eq0nUMx-NDN-Qn6R5AEsDh.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EKNghdXBpHdGR42ytqSwywHaHt.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EKWfc8P0TrArqm5bT45bVQHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eL6JGM6jhXkMq7tHBu7xaAHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-ElJZkOuqwoIjP1-1CR297gHaLG.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eLoq0eXlMM1lVuknX96wQgHaGZ.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eLycm_Y8WE7ZY6WLOhUtUAHaFS.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-ElZMhiBrhQMWQQCQwyW_ZgHaDq.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-Em0iy5_n5aGd8542BnBvAwHaE2.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-em1qhqwoYvg1pVf2-21rmwHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-Emacm5P4N2eoMh_1CeiRJAHaH2.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eMb-HZ_pEubs3jqzZd2qBAHaGE.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-emkyAugSllYwaJQ2fi6sdgHaE-.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EMpu8GbclV56JVpzl2YtLQHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EMwOw5UEGyc2t5QPRX5b0wHaKv.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eMXQWYjSG6CipMH_fsTKfgHaEp.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-En2C64d9zZIVUrDT43L80wAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-ENAm0VDOw1rB7OuOWg6pHwHaE9.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-enQ1XXylQNdDRsvFW4Y-xgHaFL.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EnxF5XDX-FIvwii221kMKAHaGC.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-en_D5fAFLpzxM0g4eBWUNAHaFT.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eOKachkbApqJhXoiyCUzogHaFi.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EopgdtGjSzzni163DzEdQAHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eo_3TVR2BAbwlj0_aaJ_WQHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EPIMAP5PQMmHXfWY8gkShAHaGP.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EpW2s60w-gey5_Z4aMQHHQHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EPY0CIxVktULsYRlU8xArQHaE9.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EQkV2pf3Eo9SrcIsDJ14FwHaGA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eQn5sWrl82QODcYjG4MeugAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eqVTkL3OHgcexaQVWHRfJQHaFc.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-Er5-rpgfTiqWHs92mNMXPAHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-ERgraPYeZiT_ijdmaMa4iQHaH7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-ErO5a1ei5hghPK69Lp_6OAHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-Es3E7TIyQIu_pMRpSVVnAgHaHC.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-ESfbWMjPWwPkkROjbjsf3QHaF1.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-ESGL-AHPA3QXZj0yXzuV_gHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-ESGr_XP50Xgvmq6cAumHEQHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eSJzqlP2dC3Ihb9dCbRGwwHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eslYTabvCFcWTUSYeFW5dgHaHx.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-esv5VoZN2EvjERgH0zeJAAHaFU.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-ETaHuB1hck5YNmRBlwA4agHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EtJeO8uJqOL0RrrtqjWKAgHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eTovnKQCeQQp8MjX8r5lhQAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eTRaUVQ_RCSIr6ALG38eRwHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eTreMoA_fR3bRnaflqqdwAHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-etV3ippjvMmhKlKOmIS-XAHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eTzn-vmK9AZulVLRDLB4kAHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-euCB2EgPBi_C3wv_AdKFkgHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eUGT07DhK5Zhr_ucq0AYYwHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EuINlB0tY8Bc28WD6KaduAHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EvSdpNE07CM1LRFKlkgJaQHaFP.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-evyJGFibs7pmU6zqzOtjcwEUEs.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EW6Gm3UyDTO4P-EorznQ_wHaF6.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-Ew8FHgz3z-FbGIUYjFjh8QHaGJ.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EW9_N_-fAIJW_HQaND4WDQHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EwkvaW5ZwVmRsVrjDpKLzQHaHa.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-ewo914dqzprviSHQxzCPCgHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-ewtbbUhJp4koG6tWAp3n8QHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-ewuJQMmLfVmZsfWH_rGfsQHaFf.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-ExD2ckN1oqqkmAwZOcKp3wHaIv.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-exE-ugBhrenOwXzBFLBnRAHaHa.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-Exssc9TB9LZm9ZmSnCn2uAHaF7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EXXygRxzCmI5iYdqytv0EAHaJ4.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-exykQpumJULMuMBb4yzACQHaGw.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-Ey1v-3QtsvCDKl9ldBx_IwHaFk.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EyokADVCAkBSK1CfQ9V_zwHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eYr4GcfiRmivKBBVFEAvYQAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-eZ1jc_aCejRktCOuOdvvagHaFi.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EzvFJcDeX5LB3VjleDtdrwHaHa.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-EzWcuGF366yCMU8-9WKsWwHaFu.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-E_2HjO-wLwMxWfbUJrGznQHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-e_Mo7LZr6q4NifLV9i8dPgHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-E_tjWPTTdqvId_FpHitT-gAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-F-CRlG4DhXEuA4pA9KgfRwHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-f-g-cdwHYtTvwH0e2T4juwHaFT.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-f-LzAW-djrb2Y8LhYYO4dAHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-F0g5gdSdPWco3poJbw4YaQHaEn.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-F0q3TT4m0PLK0ITeTooeSAAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-f12jQ06XMTkQYiW_6YiyAgHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-f1dG0fW3FRmYg8VhFqgWmQHaFk.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-f1VOPafAANjSDvEDb22wcQHaE9.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-F1WMIjKFh92Cix9bKHwEEAAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-F28-H-blnp-eX531zcDBvQHaGD.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-F2OYRrQSwxQyzTUEhIRADwHaOa.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-f2PbYlsD8QeQue5aNiUzEQAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-F3n-VCqjLjL874r6bi0MUwHaF9.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-F3R7AG_h3xFDQGldVvQagQAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-F5hBp7ULGmR0rLD-YwIsbQHaFE.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-F5YfvA-bGOFEhHVwDosAKgHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-F6bJ84SGrGU7xI8Z4WdojgHaGI.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-F6GmcoAmoRSNAYJmWG64fwAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-f6n4wTzJyXLHvdr0PtxmVwHaLG.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-f6xvyYl_iqCKmUDshZ8sbwHaE9.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-F7f-CgrQ7ernka5L1mwEHgHaFZ.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-f7Q7PTAdF4G9geCZHl6INAHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-f8rJQtxoP5RdG-dsrknuVgHaF9.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-F99_59eeK1tWGh5GQrflTAHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-F9rH2fD-MeTQQ_WC-iYhJgHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-F9SeqIGYJ_gXDcT1vBInqAHaFS.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fAf2fvTimljlwGkQLq1nrwAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FaLjs8l4l3jSCpOOvDUNxAAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fALK1ozhWupBsUscNLGfLwHgHP.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FaqwkCiLHQgVOq7Ef_cnDQAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-Fb0ET9KxOv3DeZwutRbqTQHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fbAFnGDYJHsH3GUli0nFfgHaFA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fbEKowkdVZn96f_VJZa6AgHaGg.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fBG-ZUxQwlyaWcrBSpdzlQHaEI.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fbiZiMN2MWIsehoLf76uhQHaHD.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fc3p16bc-mcbLTryaRCzSQHaGC.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FChcaJ-yZMTftRjPbCRNzAHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fcmPfp8d27oojl3tsw-YfwHaGF.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FDbGratDIOLlolV-e_0WaQHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fDDgJ7n_ptcEvhr_FHN7PAHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FdeEvviqvPG_UsyFiLqA7gHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FDn46SxtBtO5SBI2dhyzkgAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fdP0MQ8WTT7i36wCVVMTrQHaEK.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fDtauUI9EoRxoR3xuAfw0AHaGP.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fe5Xx6obuNTbLW0q11zfxAHaFv.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FEbWtQgxDM_3pxWUnS4M8QHaF9.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FEcc3Qic5JpAj3xUGblFxwHaFB.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FEeg_llyWApediy6aRGnbgHaFL.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FF3ET2OVYzy27tKhFhfcdwHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fFiUbd1DzYZWJ6AJt6Sf7QHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FFrJsUJAGdFaFJrT1oTbNAHaGq.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FfT1PAtavv25hWe8PWSN0wHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fGI6kII_u6QFrohSaONEQQHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FGIKqAyosk-CTihNKuOdCQHaEc.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fGO2YFPBAPl8PPYDXWlyYQHaF0.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FgoOSLqW4d15JmZ3MxLncwHaFS.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fGP9FXk3js9dYQsaXgrkqQHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FGS77EeFqIi3fux5knbDegHaGB.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-Fgy6tz0f_AUKMJ3KmrSBXgHaEe.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fg_PQHSUnh41IhddRqLu0AHaHa.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-Fh6zV86GO7V4kep3YnXD1wHaDr.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FHAmKOflURv5U20ve1x_jwHaFb.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fHDnFKGo7Dfzy-Lq3SjllwHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FHkLS2nSrjIArEwIh6igtwHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FhKnfsz_IFLAaPnnun_GbgAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-Fhp9bUnUqo9ByuwgloAkSAHaGU.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fHScTbjb5HE2mlyx1d7u5gHaED.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FhuUFungIvULqcFPkXSPFgHaGC.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fi-X4s4Ft1f6Rh8SGXUp5gHaKY.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fi1oRpSm3actA9bKc7ZiUAHaEK.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fi7dzQ6Xs-7E1ZedF1TyVAHaGR.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fIE16CvxaHeE7iw3hk7XzgHaF7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fIepTvmNkT-cmqcblbz6yQHaE_.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fjWupXou8Ks9J0qIaT7c2wEjEs.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-Fjzwo_SKIt_dQI8ER7VtiQAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FK6Y8wNUzQ4Kyr-zPxUU8wHaGc.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FK9WDurdKKug_tZ5dQrOmAHaJs.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FKEx3TCdDI67CxI9B_rIOwHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fKTLztpVHpmNTJF3P9-8PgHaHX.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fl2THMAoMSl8mVVC-MmJYQHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fl6NVdNYulY6oZ0oMkPFcwHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-flEAF78b7EbAUUSvHH60GwHaHC.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fLNDlKI0x0TxY0WMyZESoQHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fL_3iUEfNPl9oBH-hZroFAHaFi.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fm6qsp9UTIoAAOYIAZt2QAHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fmcqM_NRlWzkc5muZ9kLvQHaE6.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fMfi87lQEPkCzRtuHFpfBQHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FmilYKpC9SMnqqLaqoEPJwHaGD.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FmqsJyUf4wB5700ISOlzEQHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FMRPqfqKJiyjnd1NvaY_CQHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FMzg6W9jaV4k_vh5yxlrxQHaGG.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fn6t8Pj2RXiXXfREfmyVbAHaFq.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fNacjFELc7_p7YTXDLSoIQHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fnb8Rcavsh6j7L5O-qN4qwEyDM.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fnP8H7Sg_NMd_7FLxP3lBwHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fnrDN_iCBbVmoF9mwZJBnAHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FNT-Q1JD7rnIgdU0sSdDAgHaDQ.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fny38CyrqJ9oh11pxchtGgHaFn.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-Fo1aWtRVSlxRga-WuVxSogHaF6.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FO3b6gbHEbyE-_RHF-qIRAHaFi.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FOK4pnBMmaF4MZRrY5PK4AHaFi.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fOTMjh4XOjNSlcsm78YrdQHaJQ.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fP4U_1zVCJLgGTrgtWbz3gHaGH.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FpA9zMuS3RQrVPuLStP-DwHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fPBI8pNKStJdwWaIvopiigE1DK.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fptm1JrxZPzb9zpt4QUn2gHaHc.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FpWATHCrBBJY4N9sQqbMMAHaEo.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FpxVemyx7mAVk0BpZvAbrwEsC7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fqRNfD7ISXbAYdqo5bcDkQHaF0.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fr0_XE5NAIkTZg6YN_amiQHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fRH3DRqOdJ71AeUHFxXIBQHaFS.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-frUEpWJ2mKRjRaJgjZHJIQHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fRuTkPzOChayNSV_Wc8a-AHaFm.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-frYKOaaMsmNguLuW32flZwAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-frYTN_gttIbTLNSAIWckCQHaIM.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FR_nZIqy1Ksit5k1l6WFTQHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-Fs8Kzj5q1Czwzeaej0dm_QHaFT.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fshpCxmjSy7rt9qT0HjzawHaFk.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fSQOfG-rk5gOmNjGAnn_9wHaF7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-ftoQOF8bk7OYfaRvAlLkTwHaFJ.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FtR73X_026nuC99UK1Ar_AHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-ftWTxr-mQccUKL1mZlexrwHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fu6Qli4CqH4VwviBJfuOUAHaGH.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FUcoG5VSNVbqMBu8dMuBlgHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FuFq85L51hrmOFov99cmnAEMEs.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fuHI86Y9ZxdSEGWi48OE-gEsEi.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fuLjBeievYntRpd2ScCqoAEsEh.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FulX54e5k6lKCty1YOaMLAHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FutccEviI184d7cK-SI6UAHaG7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fUyZQ71OK-7pPTRwzqdmjwHaHa.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fUzLNLySj_JOHiTMRtNonwHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FV80RGTg8Kyk-f8bKCywEAHaGf.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fVnWfb562qPNUXrrOf_z8QHaF8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FWHHDbT_Sx5p2BUGD0JF5QHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FwhldIm_8K3WxYmwC0YwEAHaFT.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fWMj4yTvliusjHfDdH9XCwHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FWP5p33nmwbPWyNdQ64rRAHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FwwrQtJ0OLE83enOSRGQ7wHaFH.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FXgDq6uJO8Bt5wP11db47gHaFD.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fXmVXAUSCw1ZLWhnqeA_wQAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FxydUyngNlHwAjNdvvpyYwHaFw.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-Fy67FmM6XQxj3RypE5D5OgHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FyfB_E77S4_41CSq0WjfRQHaFG.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FYilS0IDwbdCVmng39ZfeQAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-Fyk4qHu_V7T7ivGFU5BsyAHaEk.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fytyFTcnUCqD-z1t96O7GgHaFS.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fYVaFKWfpom5NJwKdb2I8gHaE5.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FYvu0osRQ4O8LK3qB5k4pAHaIj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-FZ0DZF3mj7NFaZR01paxPwHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-fZz5oXC2Br3bxicD8aP0-AHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-F_Tc7vKUXc8po2VNDLDhpwHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-G0MkJoc2Ym3DGwKAr6BwHAHaG1.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-G0oipksrEVemcn__-KugSQHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-g1Gw08b0mwS1RXxJ_1x0ZQAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-G1vC9x2zkmKBxOTyGrTZVAHaJ3.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-G29OsRcTA9kDhNJWumexywHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-G2p8AqQRu9egLSpUF672RwHaFT.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-G2VkVO3uwbwUtzDp4d_a8QHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-g3KmRudt4kI0Hbni7S-JGAHaJP.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-g4i91pFDIaDj8Fq3I1F-6gHaFc.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-G4pN9DA0EGR3roO-yg3D_QHaFF.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-G4rsrNTwaJGlAoIcFWiwVwHaJb.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-g4tMf3wcKZRt0UwKem68xgAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-g4wGZ4HrdK3b6UPdZiTq3QHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-g5p_-K6SZr48kRfRTGkxlAHaHN.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-g5qzTh5zouKRVchQXNeqswHaF0.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-g5_3ZdjAGfbhW3SZ3ciCqwHaFo.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-g6w_2dtDtdNK53DJbrSIRwHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-g7cPx9e2Aok7uSZ-H9m7sQHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-g7GYJ_iQv4e1hEVrWfwLKwHaH4.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-g7pLEYp8WdZvjMsWcaAriQAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-g7tZYI9hya2FhEi1G9vM7QAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-G92N9iVYMDTf9yLJhAWcRAHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-G9VEN7VfiJrV_DFxsxhCPwHaFB.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-g9xrk_d6a0tUdh_pdz0gcQHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gA29-BjLJAmA3C3sS6ct9wAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GA7WS4ZDNhNGTeQVpt7ypwHaFk.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GAAAdH_8KXKcWFVGEu4-UQHaFU.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GaJY8q-8Ue0x-ncuLyYV5gHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gaKMPsFWf7xJ-VP92h-UEAHaE-.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gA_dEcMA5dhjDIIeBCGABAHaFE.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GbHrzsIDj3gnfFbFQHJlfgHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GBjG4dq5j0wYkNyfa2FwXAHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GBKlMLL1bk6wR9uIl-7K4wHaE9.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gbvCZu96WEYVKUpkmv2_qAHaFg.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gBVNjm_Qan_KKU-Af0zPdAHaGT.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GB_5oZZj1R60w3MInJmLOgHaFk.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gCaAOwTVJyScBZac_Qas7AHaDQ.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gcc9lkFJSduiub5HcjsQ1AHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gcqTrIrAUmy6eyP7mCUqNgHaFp.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gcr890BFOWYVZYQa_LXSjAHaG-.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gCYYLiXuijIG5JSH9SHamQHaF0.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gCZwK-nLRxB5U0Ylqp46tAHaEo.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GDFXSTMRMABFqDLnKPCMlgHaFm.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GDqIPzrhJuTIsGnRxc-Q8AAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gE30VOA1mWEzaXWxWvaR3QAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GeclwLkdyS9f-NLVYp-qVQHaI9.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GegDQe6WY2V8TRLSF301_gHaIz.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GEHP0ojJFgQ5XJw_NAfsjwHaF7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gejhFFZqkRdxvcc3tuJymAHaF0.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GEkDmZIeXCa87EFvzryO-gHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gELPILmYvApbxIQKFCnPPQHaEu.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-geOx-JQ3DpPAPugMR1uguwAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GEWXurp0SxEgcl9-SQzNrAHaGJ.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gF50rfJOpswJmTmStfjZLQHaE2.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gf5NQSZlfxJIbxdP6nAmiAHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gF7lSoJ7XagLqplEcqdemgHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GfMJXS0yMp0dO0613A1x9gHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GG32OSrrE5UXwpOWSNOUFAHaHb.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gG4Z8jQEIJyUQMBG1Z4NNAHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gg7d0zR-oGV2_IXSRmcZ3wHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GGaUFEB5J0ja66FJGCeeDgHaHa.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GGbDY--kigokv-p8eVl5ZgHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-Ggg5-YZPug9jKDqYHK0-xAEsDc.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gGK4xtwPmfb4adcYXNQKGAHaGp.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-ggr54WreNdjioHv_UvtRZQHaFL.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gg_EV6rBj6yTLiBI5sVPgAHaH-.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gh3rqw62xeME2WQb_ADm8QHaGw.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GHPQmFP8Ec__YQZ_cgmD8AHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-ghRoEqgrUWyUEIaCLPeElwHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gHTRUkGF7pG9pz5K7aE-JwHaHO.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GI1f40qH0yBw3jo9a3bErQHaHO.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gi4fO-EGsTRlVab15OiR8AHaHa.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-giezsU3GG1RWMDUMIKZzaQHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-giqaCUlRtAxYnjYIAg9xzQHaJ4.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GiXm07UIyCmfMC7lsBYABAHaFk.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-giYY2LsT49rrgRk6zPlGugHaHa.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GJDfgTilgFG8VqpGyYnMHgHaFH.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gjDpY-zfzjWdL6Y3PWsCiAHaIN.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-Gje11rkzxfWHKZ1grvUhZQHaFS.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GjPUDWgG3adSbLkRZvBtOwEsDh.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GJQMyJM_aN8RV-TPPIQZJgAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GjScRWVxCNuA8CUrpNCAFQHaEJ.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gjzQtR9vNGk42G3zOc8f2AHaFD.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gk0GVZUzOkQ0-UZYSQ3WUwHaJ4.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gKWDukUGZt31YCEKTcQ32gHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GK_FU1rWrgJFAcSN_1VdjgHaG1.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gLFk_8e7yz8hNYA_TDMf3QHaHm.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gLn2jGVcDaSh35nEMCb_hAHaE9.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gLnU2njttmViUS0zWlYQQwHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gM15Pf0VJota4DZ-xayVwAHaFp.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GmAW4QD4OIWBCA6Z9sMpcgEsDx.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GmlaCaZ1V4Yvo_2uWXwsTgAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gmURK5FoE89BW_4voPMsuQHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GMVzvoQZrgxLHViYY5p7BAEsDh.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gNeg4aBdOZQATyHlfn8z2AAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gNIsTamv-J2wjgPqXuTB4AAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GnJd2TqZgSzLZ1JKqgh09gHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gNKBhIsl1h2WFJG0UkulBgHaFT.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gnrcBD7-Lv4PgzLmeIJPjgHaLO.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gNUfyFgomrBv4uLNFvOKnQHaN0.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gOeJqUaxwAxSpGxs4FR1NQHaLH.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GOmmGdwEAZckL9f8hj5rzAHaFC.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-goODL4wxySDT3d_iZ2_BgQHaFL.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GP-QQcuJV9t3AqMOn5HeqgHaG4.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gpbHMnWLg_iOWse2KMqd_QHaGn.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gPImqTbluztTG1BStSaJ4gHaEK.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GpYL7QtIn_0xfhMS-3CkVwHaFo.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gQCPaokfCctDG-UhEUKjtAHaFm.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-Gqd_5GLYGwmZCDZS-ylFuAHaFG.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gqm68Df8moHky0S8MYHn_gHaGl.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gqpJiMu1LScGJ3ay3H2cKwHaIX.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gqvhiyel9oTEjmoQAPoQfQHaG6.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gr2CSDCm1T3tOSzB8R90AAHaKw.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GRAhaDb1J62Na3gOq6xL8QHaHa.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gRffNTPqOU1VNTlpVKPLGQHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-grgSEk5WXm43o9Zj_XUmUwHaE9.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GrU-RyxrndIcRrRABRUqJgHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-Gs6HWs39SjRmBpVNatiZbgEsDz.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gSC1XI5woc_9lk3MqZspBgHaH3.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gSIPPiMyDE4DbAqUjPXggQHaD6.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GS_7HsqYmpEmsMMPbjjQpAHaFi.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GT0HuR6mCC9jBj8DKnvdOwHaFS.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-Gt5CiKuIRfA44qabNpPCLgHaGt.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GtjmFQmTYgySbQATcs3QMAHaE6.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GU2oSgCfQdHKzzXqJj9RUQHaEK.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gU7i_R9hwFMzhO4rW_ClXQHaGL.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gUTNDGtX0xpZbRyOxnQC9gAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gv97_Qgnc7E7f9y6Kh6fNwHaE6.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-Gvd-aQt44o7lJ04On8pTVQHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GvfldB00KzTxWMCqJXaMBQHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GVRYYXIRlduYORyauqV4VgHaKy.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GVz4L2icOv-PHSd2Uh0_QAHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gW2qAMQpqVfTaqeObGYAXAAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gwnyXhcDmJBDE78XWzT2qwHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GwUWfQtG1EDXurmebs-LHgHaGz.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gWzu6IZi_3rhmrNzxRjOXgHaHf.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gxEA0H-toXjW8NTZDIRVbgHaFv.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gxh7VpmIenEz2wetrFrHLwHaHz.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GXHHiX4jFZzJK0KYLCEG1wHaFc.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gXkw8eyrnY19blMCGd-n3wHaF7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GxQtDJR6Oy582tcRDI9vYQHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gYbRTDk1dtF9tiP0MPx_hQHaFi.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gYfZC-x6QG_aggM1QZ9sYAHaID.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gyGceYDouT8Hxaj6JhjXYQHaLH.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gYk8xe5Gf1xK6CuguXUKHQHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GyNObRTpn9tVxbLjSxwrCAHaFx.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GZ8zUa5xLsUQxOPYAHXRUwHaE1.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gZ9zs0nw47lcN7Eqn92pfwHaGT.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GZKG6Pe6J5j1Ncq6XacdaAHaF7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GZnUIe4HxYIf3LOyHBKUJQHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gzQrIreBvD6cqySz5t2FawHaHX.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GZTtuZOiyp2zeIIQ6C2VDwHaF9.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-gzUtJ4ntKvAX_7fareX1fgHaLJ.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-GZ_7XYpqqkrS1dS2JvZIKwHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-g_jLJQ6NRQB39o7i4xGlSwHaHH.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-G_wGHtV9hhpw60T0YP7eTAAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-H-7j6C4cFfKr91jcbHvkvwHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-H-lOD8RAB1ZWa00kF6NtBQHaFL.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-h-MQyinV3sCk5yBFFm7JygAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-h-pgu8jxw53ovhTs6rHkQwAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-H0eqfVpnUKPwH1CFeX5kpwHaHL.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-H0uj7snRbi2UwqUXoTMjfQHaE6.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-H0_Z9FyqbiSDCjjynC2D0gHaEL.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-h2ilMXFNfRuXDzsQV2mT5gHaGt.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-H2Q7HYKSa15b82ElZsXNTAHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-H3IhdvgQc5VZ_OVPJ--fMgHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-h3UmhvvpTtcnAQvZtgdbeAHaLH.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-h3_2f2EkBbY8av6z2DU9QQHaK7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-h48wpz1X1iG2r1Tbsq_etgHaGX.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-H4pJe1v6lFnJnsrctkqqIwHaGW.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-h50lX8yvVNlqs4AJ8yv7aAHaEn.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-H54AcVjKx7nvhcg1mH41awHaFP.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-h5AxK0ZA6O4vdJpWO6tjXAHaEL.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-h5TGo_ilGeLefgsEOYd2gwHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-h6jqF5nIHwOoen-bUis3fQHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-H6mo_z-7zDIHsuDkZ5jc8QAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-h8NJPQfS7mncnT0ofHynCAHaEL.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-h9wVDnl54w0ANBLjSy5AugENDo.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-HaamHkxcQ5EiNKR5b5rOnwHaFm.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-HadROnoU70YGSCZTlAtGDwHaFG.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-HAVOCOysuApNHwLtyyn6_QHaMX.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-Hb-ai5i9jRMx6HUYpRxZ4AHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-hBek8BKuyYgh2Bgwn-ZEjwHaG_.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-HBFLziPp1iGMOy4LLKjybAHaFU.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-HBOdTFAdm1rd0F2z6HvZtQHaHa.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-hBqsXqPOEAbWExKKwRTjzwHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-HBTFf3yQzyI_NmgHOB3jbQHaFw.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-hcCdEEqKihc9ckxM4VuGJwHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-hD5wJmes5xZ0fZiZeHoZewHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-HdAdBubVBNFfHoNohqomfgHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-hddl2zkp7RsJzUs6K9TOwgHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-hdDPIv5VSvE6SOPltgPrsQHaJD.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-HDGpqCyYuiv0Zj0vdgJtVwHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-hdik6nnyx9Iamz3nQLJuiwHaFL.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-hdkMt9xsZCbaRMh4cY9CawHaF_.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-HDlrI7icnierVddv8yoXDgHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-hDQruPAX9skTE7fOzvKXAQEsDw.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-HdXePLx5BJSVacM8038rBgHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-HE1JEgO98g69145qsYgonQHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-HEcQeKUzPYjIITTU2S6KGgHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-hEkyRhiXOH6T29U0uaUDbgHaFO.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-HF0Fcq6kN0su6ktTARQ9WgHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-hF9vAjT3tKh1qfExjX8UwwHaFe.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-HFaATUywqLDWo9tYa3abVgHaFk.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-hFjlxEEemkU8yrHFVSSmBwHaFn.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-HFz2pkGh8At5swPJ-Lc1YgHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-hg0OxvX-qD2fi0ds3binigHaFS.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-Hg1DZwF71Ch33rBe5ZAy9AHaF7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-hGEgN3hznUOz6RyTmLtwAAHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-hggUejAq268kUi1r3GpVOgHaFo.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-hgP2fF05te9SRyMU5M5wygHaHa.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-hgpoJJRufizx8RAlere_CAHaEg.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-HHDMwxYinDms21P53ehm8QHaHw.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-HhdPwGCFFcqlv998DSFH1gHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-HHrSSeccaZG8529aj4vd2QHaGz.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-HHtmTGN5nD0umtRq8xeAUAHaE-.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-hi6vmv3YyPYsw_An1eO6_gAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-HiCE3XtjLYBbA-VJu8bQ8QHaFR.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-hIS5IxQq5rLzPF87je5d3QHaE6.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-hj7LShHem3fT7326Yd0r4gHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-HjNy0JvSoTt6rqCt0H7v3QAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-HJOYJdZsjMKQKrac_vctlwHaHO.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/spider/OIP-HjwK4SponOzeMs9_zfuteQHaFj.jpeg
# ...
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-xOCABsxqKkUg5eC-rew1XAHaDt.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-xoCKe7GLdJZ05cnkh1JPggHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-XQ0PNyj49o-0ygJc4xq6WgHaF7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-xq5e35WizCPvhmM2Md3RdAHaEK.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-XqwdlRXhVZG6niIOcTkgEQHaGY.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-XQWwi7XmmHr13OVpGlyMMgAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-xSn8zdtlbh6CTVeNKLzh5wHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-Xt-AuqdJUAX20roecYTF1QHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-xU25y2pehtyd7kxR-Y55YAHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-XuSeQLqwyk7bN2usyiBJiQHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-XvfEzjqAC3kjd_E6JV8h8AHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-XwTU7qA85GdLul6ef7jyLQHaGb.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-xXppqCqAAttfrEER-aFOOAHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-xys6DWhLu5kKtRLB3ThrzwHaFc.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-xziVYV8vGTFjF4CzDHuipwHaLH.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-xzKxHldb5bZYJCnnBH91twHaEK.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-xzZzCw8UwEOEf14Tb45O0gHaFg.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-x_19ZG16UzgBUjdOouHrbAHaE6.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-x_5yzPAHxHrgrGGFFDtJRAHaFP.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-Y-UtszuxgHNzwtUE15s5rAHaEK.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-Y-X8BbNXpQyqGzz1HXbG_wAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-Y3J40kPpx5SvYguQ4MzCsAHaEq.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-y4IxvJSvX7MqsAlnk49ITgHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-Y7bWufEYCjKLObQa1HM6mQHaFS.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-YAvnfMi9Ffq4da3syr8-rAAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-yB4QSPjlcdYGQwizOZAJogHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-YbHUEBJHfwoQc7TpkokeEgHaE9.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-ybqM9IuDWY2tkqM3clTWNQHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-yBv80z117f6vV4EN8e7d4QHaLL.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-ycxyJ5k8La6dDi2GbEwmLQHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-Yd1ZIuA1cOZSWkJW74lzIwHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-YdCAP-1wOVr9rJTIAcTGbQHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-ye7thQ5-qCtZxXZJqYwnbwAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-yEDzihMNoXF-xOUTAU6Q3AHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-YFzMgWLbLG9ssDQ-4wdhqwAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-YG9IY82WTxPe96N6BSqQ3gHaEK.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-ygDZzFQIlEpSCXKwJPoG8QAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-ygfPaNnmUlnetNn9zAZMdQHaEo.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-YGg61vIqhZAyqaVE5QhLiQHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-yHTeNq9R8DDfsXFXfI7w8gHaFc.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-yIFOn20fxhRcJ29O9uJx7gHaEo.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-yjz3HDAtK0E94baTZOq0vAHaFP.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-yka4v1ZUQe3hUWhp6Aq7tQAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-YkTZSqE8grCOl8j0wjQzuAAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-YLBNzdH1VeVPLNLUI-r3BQHaE0.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-YlE_6-e4sx9KCCHOZzEQdAHaE4.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-yLHtUL4T95AK7x2Va9aZ4QHaGQ.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-yLJovM5_nAzGbqDQZ1SEhwHaJo.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-yLvvDGYlMAhhXBkTPvA4IQHaFi.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-YMMdROABkwMWWwGXlSI-mwHaLH.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-YMPwpCj1fT8H06HyBSbKfQHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-Yn7gTUmMkgKDvV6FyYzpiQHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-yNOvbu6jPEikpaoU5uaQ1QAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-ynPgue9MX5T_rLNTIdixTQHaGL.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-yo4BhLWnzy03EhF3EMpkFAHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-YocGV66oI1W9WLKWYC_anAHaLG.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-yPnoy1IkDhxesASdsRhxqwAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-ypvnupPWTKy395NuuNHdBwHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-yqiDUfEUWjYGAFDe2eyHlwHaE6.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-Yr8nssZxBRKmlj_4bVctjQHaGE.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-YrjJuzczPWtnmM49AzAOJwHaE4.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-YsLGeTEPZbhzrBufsN4VvQHaE-.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-YSvTbdQNxAe02w2JYQGj4QAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-ytfyiMBXwQeO9BmVEXQ1rwHaI8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-Yt_4ZnI4BgCOX1uHV1jaKAAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-yUYBYcKSr4yp9UZPqv8v6QHaE3.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-ywR1iTzpP4Rr083pQ1LmvAHaFz.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-yXl5yDIFFDeOErg2lXEitgHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-YXLRLwFA-TTHX5BWmfePRQHaKR.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-yYkUFqt3-Luv8yTCWGJF5wHaFq.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-Yzl3jUFdXce31xAlj4VcHAHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-YZv_9IdUTJrHFxxlsjt4_AHaGp.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-YzWqoT2FDnOEiJ_BFAZGqQHaLH.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-y_LhgCj_SFDeUfpT519gXQHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-Y_qUC89aWJb7hu_Iw7KfmgHaFU.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-z-1uhOhwztGOqDulrEaKOgHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-Z-jHLNDqdGjAH6-c0PNxOAHaE6.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-z1uhlwHr5D31NRF1hCS_GQHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-Z3L_2AYJiiAf6UberJpaFwHaE-.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-Z3WkMp9I6ReS2K3YnutuqAHaEj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-Z4k5qvpiHOtA6Erk8iaYrwHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-z4OZ9Sudx_MmdoZJLDLxuQHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-z4SqJD-ixyK2xXSMP3oZQAHaE6.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-Z4uwhWe_K2BIhvR9bjnvPQHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-Z5JOIW51WbHPL6vrE8j6uwHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-z6yQWqUVgODwQjlONFGFrAHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-z9Zuh6Td4hQNO0BOP7VPlwHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-ZbcQ7Qw6og_EcmPchrWPPgAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-zBsym6h7uIvfZtE52lwYYAHaJ4.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-ZCXag3dGIjz8qq-SU9a8IwHaGE.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-ZDyLe7SCh6JWyZ9Aq4v_PwHaFE.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-ZeEADmerTlGWcuacKPW20wHaF5.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-zEF5uw6Km8yKjLpbi1EK0wHaEK.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-zEUYFDm5HzhJ7-wwQ84RZAHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-ZF1oYOlJsV6QU6VTd8HxYAHaE5.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-zfDq_DKh-s5jdzFKjLuMJAHaFy.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-zFWF4AQsVuw2a70awHTbXAAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-ZFxY-A1tVIi381bQsUvuSAAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-ZF_JKz4JANMMO5hoGFtbsAHaE9.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-ZGnxE9nAtbq0cmgNyEvDUAHaLJ.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-Zgpal1X51YpES2SXbO2eQgHaFs.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-zGQZIl0zO8kIxvK_A6zgTgHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-ZH-7-Z2Ip_sPzeKlfGl_9gHaFk.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-Zh384dOlRCWBqPO4Sg5zyQHaEX.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-zhJ-pBR-0ryoI4c8Y00XIgHaD3.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-zhLz2NNZOh527Bvrz2dlpAHaFw.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-ZleIH_fUEq6QLqg0r9SDawHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-zM3-CoKympHhLnHTWerTmQAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-ZmMwHrIxTMAvXZvq4FT10AHaGF.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-zmrCT577lLJ3FGpqKbGFAAHaGl.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-zoNeR-sDqoFiOkMJrGWv-gHaG9.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-ZoYZzBjBgliTblAgXK-udwHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-zp2D7FAPeubKw4S1WChEfQHaEo.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-zpD7SDCbIqwjYm2A06OybwHaID.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-Zps-VUJrgjMr4b2rRNmWXgHaFI.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-zpZ5t_rN3DA6xByG0o05WwAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-zSvrkLxfcHGXLXGA0HuAhQHaFY.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-ZtKNxAUUKn5r_9r4y1FC7QHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-ZtyEFE8GseIcE5d63-2LmAAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-ZVTOxplj11Gwd72wxUjlEAHaEO.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-zwWLqRd95U-BjagmhkAgoQHaFK.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-zYBdcDlCOtl_jVRthapcBAHaJr.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-ZyC8rpwzku88sGwbY9JddAHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-zyCc-DDxjCSB5m9DR3uNKQHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-zYD_2_Leq1OPNGZxVLMlkQHaJh.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-Zy_a3TFFvWl8irb3aIy-HwHaG6.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-ZzfOEtuQSRUofPHSZob0UAHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-ZzV2cnnarfBv1b0Xj7cvMwHaEX.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-zzy5kEbHuGBWXZ3c-D85aAHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_1fZ4ZAaldRi0hgUW7DVuQHaFr.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_5bWJ7SoPigN4PgV6UozJAHaEo.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_7pz-4WgSloa6KRjq6DozAHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_b7M9TMyyPRiNxAbf_EmkQHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_CfAAHdwS_7kSIEuKo_LhQHaG7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_cwStB4RUBpoAm0dmJ0hIAHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_CygoxlOH2ORAFiulW4WpQHaFI.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_drWCjlWkUA3_BvlQCemqAHaEo.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_dVEHaJdv_2qGvKpQOVEJwHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_etMNqBBhvthcoMi5V2zCQHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_flk9r3BRf3VxU5zWSep5QHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_GGhpT1ecnjpxh5w86ainwHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_GXcWuoMOJ-aLnFOH9U52gAAAA.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_jpMl-tHPdybTv67n6nNiQHaE5.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_k5JGFJdEOADeeI6S5OZLgHaEw.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_kiyj8R2JYihtRF0_MURRQHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_lEB2E_BnSgc4Peh-rZ3rQHaFf.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_Lqu0P1huPpO-BYjvUuNpwHaE8.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_LQ_PTWmYyR9N_fPk5W49AHaHF.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_LTqtCctZiQNdcmxKsvp7QHaEm.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_NTjryC6siDm7PEsYmY-vQHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_oc6ePnvxzxC6FJwE6TxHQHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_pyUwWG1Gyb1Sr5v-SVk_QHaEo.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_QADUIj-ZwXUHDnTkLUivwHaJ_.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_rMOzD8-J2Am0NvqL05rNgEgDY.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_s7hp8AbJLmAh4w8T_f2UgHaHa.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_t1IBSscCgc_UdXLBsdQJwHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_U7JiIoYjbWPqmmmmdsvJwHaF5.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_VBkNQd_MZI4xoemUb-FtAHaE7.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_WyHKgREia-4VijlL6DNswHaFj.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_xFGMN0UbYduHdiXQ1maZAHaIF.jpeg
#   inflating: /content/drive/MyDrive/raw-img/raw-img/squirrel/OIP-_XkUFCI2duAyKDD9utKQzgHaFc.jpeg

# %% [markdown]
# ## Upload Dataset to Google Drive (Optional)
#
# If using Google Drive, mount it and specify the path:

# %%
# Uncomment to mount Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# Set your data directory path
# DATA_DIR = '/content/drive/MyDrive/your-dataset-folder'
DATA_DIR = '/content/drive/MyDrive/raw-img/raw-img'  # Default: local to Colab session

# %% [markdown]
# ## Configuration
#
# All hyperparameters and training settings

# %%
from pathlib import Path

# ============= PATHS =============
BASE_DIR = Path('/content')
OUTPUT_DIR = BASE_DIR / 'outputs'
CHECKPOINT_DIR = OUTPUT_DIR / 'checkpoints'

# Create directories
OUTPUT_DIR.mkdir(exist_ok=True)
CHECKPOINT_DIR.mkdir(exist_ok=True)

# ============= MODEL CONFIGURATION =============
CLIP_MODEL_NAME = "ViT-B/32"  # Options: "ViT-B/32", "ViT-B/16", "RN50"
CLIP_EMBEDDING_DIM = 512
PROJECTION_DIM = 128
USE_PROJECTION_HEAD = True
PROJECTION_DROPOUT = 0.1

# ============= TRAINING CONFIGURATION =============
PHASE1_EPOCHS = 10  # Train only projection head
PHASE2_EPOCHS = 5   # Fine-tune CLIP + projection
TOTAL_EPOCHS = PHASE1_EPOCHS + PHASE2_EPOCHS
UNFREEZE_LAST_N_LAYERS = 2  # Number of CLIP layers to unfreeze in phase 2

# Batch size and workers
BATCH_SIZE = 32
NUM_WORKERS = 2  # For Colab

# Optimizer settings
LEARNING_RATE = 1e-4
WEIGHT_DECAY = 1e-4

# ============= TRIPLET LOSS CONFIGURATION =============
TRIPLET_MARGIN = 0.3

# ============= DATASET CONFIGURATION =============
TRAIN_VAL_SPLIT = 0.8  # 80% train, 20% validation
TRIPLETS_PER_IMAGE = 3  # Triplets per image per epoch

# ============= LOGGING CONFIGURATION =============
LOG_INTERVAL = 10
EARLY_STOPPING_PATIENCE = 5

# ============= FILE NAMES =============
BEST_MODEL_PATH = CHECKPOINT_DIR / "best_triplet_model.pth"
LAST_MODEL_PATH = CHECKPOINT_DIR / "last_triplet_model.pth"
TRAINING_LOG = OUTPUT_DIR / "training_log.csv"

# ============= REPRODUCIBILITY =============
RANDOM_SEED = 42

print("✓ Configuration loaded")
print(f"Output directory: {OUTPUT_DIR}")
print(f"Checkpoint directory: {CHECKPOINT_DIR}")
# Out:
# ✓ Configuration loaded
# Output directory: /content/outputs
# Checkpoint directory: /content/outputs/checkpoints

# %% [markdown]
# ## Import Libraries

# %%
import os
import random
import time
from collections import defaultdict
from typing import List, Dict, Tuple, Optional

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
from tqdm.auto import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import clip

# Set style
sns.set_style('darkgrid')
plt.rcParams['figure.figsize'] = (12, 6)

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA device: {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch version: 2.9.0+cu126
# CUDA available: True
# CUDA device: Tesla T4

# %% [markdown]
# ## Set Random Seed for Reproducibility

# %%
def set_seed(seed: int = 42):
    """Set random seed for reproducibility"""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    print(f"✓ Random seed set to {seed}")

set_seed(RANDOM_SEED)
# Out:
# ✓ Random seed set to 42

# %% [markdown]
# ## Dataset Classes
#
# Custom dataset for triplet learning with automatic class discovery from folder structure

# %%
class TripletImageDataset(Dataset):
    """
    Dataset that generates triplets (anchor, positive, negative) for metric learning.

    Folder structure:
    data_dir/
        class1/
            img1.jpg
            img2.jpg
        class2/
            img1.jpg
            img2.jpg
    """

    def __init__(self, root_dir: str, transform=None, triplets_per_image: int = 3,
                 subset_size: Optional[int] = None):
        self.root_dir = Path(root_dir)
        self.transform = transform
        self.triplets_per_image = triplets_per_image

        # Discover classes and build index
        self.class_to_images = self._build_class_index()
        self.classes = list(self.class_to_images.keys())

        # Flatten all image paths
        self.all_image_paths = []
        self.image_to_class = {}

        for class_name, image_paths in self.class_to_images.items():
            for img_path in image_paths:
                self.all_image_paths.append(img_path)
                self.image_to_class[img_path] = class_name

        # Apply subset if specified
        if subset_size is not None and subset_size < len(self.all_image_paths):
            self.all_image_paths = random.sample(self.all_image_paths, subset_size)

        print(f"Dataset: {len(self.classes)} classes, {len(self.all_image_paths)} images")
        print(f"Classes: {', '.join(self.classes)}")

    def _build_class_index(self) -> Dict[str, List[str]]:
        """Scan directory and build class-to-images mapping"""
        class_to_images = defaultdict(list)
        valid_extensions = {'.jpg', '.jpeg', '.png', '.bmp', '.gif', '.tiff'}

        for class_dir in self.root_dir.iterdir():
            if not class_dir.is_dir():
                continue

            class_name = class_dir.name
            for img_path in class_dir.iterdir():
                if img_path.suffix.lower() in valid_extensions:
                    class_to_images[class_name].append(str(img_path))

        # Filter out classes with too few images
        class_to_images = {k: v for k, v in class_to_images.items() if len(v) >= 2}
        return dict(class_to_images)

    def _load_and_transform_image(self, image_path: str) -> torch.Tensor:
        """Load and preprocess image"""
        image = Image.open(image_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image

    def _get_positive_sample(self, anchor_path: str, anchor_class: str) -> str:
        """Get positive sample (same class, different image)"""
        positive_candidates = [p for p in self.class_to_images[anchor_class] if p != anchor_path]
        if not positive_candidates:
            return anchor_path
        return random.choice(positive_candidates)

    def _get_negative_sample(self, anchor_class: str) -> str:
        """Get negative sample (different class)"""
        negative_classes = [c for c in self.classes if c != anchor_class]
        negative_class = random.choice(negative_classes)
        return random.choice(self.class_to_images[negative_class])

    def __len__(self) -> int:
        return len(self.all_image_paths) * self.triplets_per_image

    def __getitem__(self, idx: int) -> Tuple[torch.Tensor, torch.Tensor, torch.Tensor]:
        # Map idx to anchor image
        anchor_idx = idx // self.triplets_per_image
        anchor_path = self.all_image_paths[anchor_idx]
        anchor_class = self.image_to_class[anchor_path]

        # Get positive and negative samples
        positive_path = self._get_positive_sample(anchor_path, anchor_class)
        negative_path = self._get_negative_sample(anchor_class)

        # Load and transform images
        anchor_img = self._load_and_transform_image(anchor_path)
        positive_img = self._load_and_transform_image(positive_path)
        negative_img = self._load_and_transform_image(negative_path)

        return anchor_img, positive_img, negative_img

print("✓ Dataset class defined")
# Out:
# ✓ Dataset class defined

# %% [markdown]
# ## Model Architecture
#
# CLIP-based triplet network with optional projection head

# %%
class ProjectionHead(nn.Module):
    """Projection head to reduce dimensionality and adapt features"""

    def __init__(self, input_dim: int, output_dim: int, dropout: float = 0.1):
        super().__init__()

        self.projection = nn.Sequential(
            nn.Linear(input_dim, input_dim),
            nn.BatchNorm1d(input_dim),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout),
            nn.Linear(input_dim, output_dim)
        )

        self._init_weights()

    def _init_weights(self):
        """Initialize weights using Xavier initialization"""
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm1d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.projection(x)
        # L2 normalize to unit hypersphere
        x = F.normalize(x, p=2, dim=1)
        return x


class CLIPTripletModel(nn.Module):
    """Triplet network using CLIP image encoder with projection head"""

    def __init__(self, clip_model_name: str = "ViT-B/32", projection_dim: Optional[int] = None,
                 dropout: float = 0.1, freeze_clip: bool = True):
        super().__init__()

        # Load pretrained CLIP
        self.clip_model, _ = clip.load(clip_model_name, device="cpu")

        # Get CLIP embedding dimension
        if "RN" in clip_model_name:
            self.clip_embedding_dim = 1024 if "RN50x" in clip_model_name else 512
        else:  # ViT-based
            self.clip_embedding_dim = 768 if "ViT-L" in clip_model_name else 512

        # Freeze CLIP if specified
        if freeze_clip:
            self.freeze_clip_backbone()

        # Projection head
        self.use_projection = projection_dim is not None
        if self.use_projection:
            self.projection_head = ProjectionHead(self.clip_embedding_dim, projection_dim, dropout)
            self.output_dim = projection_dim
        else:
            self.projection_head = None
            self.output_dim = self.clip_embedding_dim

        print(f"Model: {clip_model_name}, CLIP dim: {self.clip_embedding_dim}, Output dim: {self.output_dim}")

    def freeze_clip_backbone(self):
        """Freeze all CLIP parameters"""
        for param in self.clip_model.parameters():
            param.requires_grad = False

    def unfreeze_last_n_layers(self, n: int):
        """Unfreeze last N transformer blocks of CLIP"""
        self.freeze_clip_backbone()

        if hasattr(self.clip_model.visual, 'transformer'):
            total_blocks = len(self.clip_model.visual.transformer.resblocks)
            print(f"Unfreezing last {n} of {total_blocks} transformer blocks")

            for i in range(total_blocks - n, total_blocks):
                for param in self.clip_model.visual.transformer.resblocks[i].parameters():
                    param.requires_grad = True

            # Unfreeze layer norm and projection
            if hasattr(self.clip_model.visual, 'ln_post'):
                for param in self.clip_model.visual.ln_post.parameters():
                    param.requires_grad = True

            if hasattr(self.clip_model.visual, 'proj'):
                if self.clip_model.visual.proj is not None:
                    self.clip_model.visual.proj.requires_grad = True

    def encode_image(self, image: torch.Tensor) -> torch.Tensor:
        """Encode image using CLIP and optional projection head"""
        with torch.set_grad_enabled(self.training):
            clip_features = self.clip_model.encode_image(image).float()

        if self.use_projection:
            embeddings = self.projection_head(clip_features)
        else:
            embeddings = F.normalize(clip_features, p=2, dim=1)

        return embeddings

    def forward(self, anchor: torch.Tensor, positive: torch.Tensor,
                negative: torch.Tensor) -> Tuple[torch.Tensor, torch.Tensor, torch.Tensor]:
        """Forward pass for triplet"""
        anchor_emb = self.encode_image(anchor)
        positive_emb = self.encode_image(positive)
        negative_emb = self.encode_image(negative)
        return anchor_emb, positive_emb, negative_emb

    def count_parameters(self) -> dict:
        """Count trainable and total parameters"""
        total_params = sum(p.numel() for p in self.parameters())
        trainable_params = sum(p.numel() for p in self.parameters() if p.requires_grad)
        return {
            'total': total_params,
            'trainable': trainable_params,
            'frozen': total_params - trainable_params
        }

print("✓ Model architecture defined")
# Out:
# ✓ Model architecture defined

# %% [markdown]
# ## Loss Function and Metrics

# %%
class TripletLoss(nn.Module):
    """Triplet Margin Loss for metric learning"""

    def __init__(self, margin: float = 0.3):
        super().__init__()
        self.margin = margin

    def forward(self, anchor: torch.Tensor, positive: torch.Tensor,
                negative: torch.Tensor) -> torch.Tensor:
        # Euclidean distance
        pos_dist = F.pairwise_distance(anchor, positive, p=2)
        neg_dist = F.pairwise_distance(anchor, negative, p=2)

        # Triplet loss: max(0, pos_dist - neg_dist + margin)
        losses = F.relu(pos_dist - neg_dist + self.margin)
        return losses.mean()


def compute_triplet_accuracy(anchor: torch.Tensor, positive: torch.Tensor,
                            negative: torch.Tensor, margin: float = 0.0) -> float:
    """Compute triplet accuracy: fraction where d(a,p) < d(a,n)"""
    pos_dist = F.pairwise_distance(anchor, positive, p=2)
    neg_dist = F.pairwise_distance(anchor, negative, p=2)
    correct = (pos_dist + margin < neg_dist).float().sum()
    accuracy = correct / anchor.size(0)
    return accuracy.item()

print("✓ Loss function and metrics defined")
# Out:
# ✓ Loss function and metrics defined

# %% [markdown]
# ## Trainer Class
#
# Handles training loop, validation, checkpointing, and early stopping

# %%
class TripletTrainer:
    """Trainer for triplet network with staged learning"""

    def __init__(self, model: CLIPTripletModel, train_loader: DataLoader,
                 val_loader: DataLoader, device: str = "cuda", learning_rate: float = 1e-4,
                 weight_decay: float = 1e-4, margin: float = 0.3):
        self.model = model.to(device)
        self.train_loader = train_loader
        self.val_loader = val_loader
        self.device = device

        # Loss function
        self.criterion = TripletLoss(margin=margin)

        # Optimizer
        self.optimizer = torch.optim.AdamW(
            self.model.parameters(), lr=learning_rate, weight_decay=weight_decay
        )

        # Learning rate scheduler
        self.scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
            self.optimizer, T_max=TOTAL_EPOCHS, eta_min=1e-6
        )

        # Training state
        self.current_epoch = 0
        self.best_val_loss = float('inf')
        self.best_val_accuracy = 0.0
        self.epochs_without_improvement = 0

        # Metrics
        self.train_losses = []
        self.val_losses = []
        self.train_accuracies = []
        self.val_accuracies = []

        print(f"Trainer initialized on {device}")

    def train_epoch(self) -> Tuple[float, float]:
        """Train for one epoch"""
        self.model.train()
        epoch_loss = 0.0
        epoch_accuracy = 0.0
        num_batches = 0

        pbar = tqdm(self.train_loader, desc=f"Epoch {self.current_epoch + 1} [Train]")

        for batch_idx, (anchor, positive, negative) in enumerate(pbar):
            anchor = anchor.to(self.device)
            positive = positive.to(self.device)
            negative = negative.to(self.device)

            # Forward pass
            anchor_emb, pos_emb, neg_emb = self.model(anchor, positive, negative)
            loss = self.criterion(anchor_emb, pos_emb, neg_emb)
            accuracy = compute_triplet_accuracy(anchor_emb, pos_emb, neg_emb)

            # Backward pass
            self.optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_norm=1.0)
            self.optimizer.step()

            # Accumulate metrics
            epoch_loss += loss.item()
            epoch_accuracy += accuracy
            num_batches += 1

            # Update progress bar
            if batch_idx % LOG_INTERVAL == 0:
                pbar.set_postfix({
                    'loss': f'{loss.item():.4f}',
                    'acc': f'{accuracy:.4f}',
                    'lr': f'{self.optimizer.param_groups[0]["lr"]:.2e}'
                })

        return epoch_loss / num_batches, epoch_accuracy / num_batches

    @torch.no_grad()
    def validate(self) -> Tuple[float, float]:
        """Validate on validation set"""
        self.model.eval()
        epoch_loss = 0.0
        epoch_accuracy = 0.0
        num_batches = 0

        pbar = tqdm(self.val_loader, desc=f"Epoch {self.current_epoch + 1} [Val]")

        for anchor, positive, negative in pbar:
            anchor = anchor.to(self.device)
            positive = positive.to(self.device)
            negative = negative.to(self.device)

            # Forward pass
            anchor_emb, pos_emb, neg_emb = self.model(anchor, positive, negative)
            loss = self.criterion(anchor_emb, pos_emb, neg_emb)
            accuracy = compute_triplet_accuracy(anchor_emb, pos_emb, neg_emb)

            # Accumulate metrics
            epoch_loss += loss.item()
            epoch_accuracy += accuracy
            num_batches += 1

            pbar.set_postfix({'loss': f'{loss.item():.4f}', 'acc': f'{accuracy:.4f}'})

        return epoch_loss / num_batches, epoch_accuracy / num_batches

    def save_checkpoint(self, is_best: bool = False):
        """Save model checkpoint"""
        checkpoint = {
            'epoch': self.current_epoch,
            'model_state_dict': self.model.state_dict(),
            'optimizer_state_dict': self.optimizer.state_dict(),
            'scheduler_state_dict': self.scheduler.state_dict(),
            'best_val_loss': self.best_val_loss,
            'best_val_accuracy': self.best_val_accuracy,
            'train_losses': self.train_losses,
            'val_losses': self.val_losses,
            'train_accuracies': self.train_accuracies,
            'val_accuracies': self.val_accuracies,
        }

        torch.save(checkpoint, LAST_MODEL_PATH)

        if is_best:
            torch.save(checkpoint, BEST_MODEL_PATH)
            print(f"✓ Best model saved (val_acc: {self.best_val_accuracy:.4f})")

    def train(self, num_epochs: int, phase: int = 1):
        """Train for multiple epochs"""
        print(f"\n{'='*60}\nPhase {phase} Training\n{'='*60}")

        start_epoch = self.current_epoch

        for epoch in range(start_epoch, start_epoch + num_epochs):
            self.current_epoch = epoch
            epoch_start_time = time.time()

            # Train and validate
            train_loss, train_acc = self.train_epoch()
            val_loss, val_acc = self.validate()

            # Update learning rate
            self.scheduler.step()

            # Save metrics
            self.train_losses.append(train_loss)
            self.val_losses.append(val_loss)
            self.train_accuracies.append(train_acc)
            self.val_accuracies.append(val_acc)

            # Print summary
            epoch_time = time.time() - epoch_start_time
            print(f"\nEpoch {epoch + 1}/{start_epoch + num_epochs}")
            print(f"  Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f}")
            print(f"  Val Loss:   {val_loss:.4f} | Val Acc:   {val_acc:.4f}")
            print(f"  Time: {epoch_time:.1f}s | LR: {self.optimizer.param_groups[0]['lr']:.2e}")

            # Check for improvement
            is_best = val_acc > self.best_val_accuracy

            if is_best:
                self.best_val_accuracy = val_acc
                self.best_val_loss = val_loss
                self.epochs_without_improvement = 0
            else:
                self.epochs_without_improvement += 1

            # Save checkpoint
            self.save_checkpoint(is_best=is_best)

            # Early stopping
            if EARLY_STOPPING_PATIENCE > 0:
                if self.epochs_without_improvement >= EARLY_STOPPING_PATIENCE:
                    print(f"\n⚠ Early stopping triggered after {self.epochs_without_improvement} epochs")
                    break

        print(f"\nPhase {phase} completed!")
        print(f"  Best Val Accuracy: {self.best_val_accuracy:.4f}")
        print(f"  Best Val Loss: {self.best_val_loss:.4f}")

print("✓ Trainer class defined")
# Out:
# ✓ Trainer class defined

# %% [markdown]
# ## Create DataLoaders

# %%
def get_clip_transforms(model_name: str = "ViT-B/32"):
    """Get CLIP preprocessing transforms"""
    _, preprocess = clip.load(model_name, device="cpu")
    return preprocess


def create_dataloaders(data_dir: str, batch_size: int, num_workers: int,
                      train_val_split: float = 0.8, clip_model_name: str = "ViT-B/32",
                      triplets_per_image: int = 3, subset_size: Optional[int] = None):
    """Create train and validation dataloaders"""

    # Get CLIP transforms
    transform = get_clip_transforms(clip_model_name)

    # Create full dataset
    full_dataset = TripletImageDataset(
        root_dir=data_dir, transform=transform,
        triplets_per_image=triplets_per_image, subset_size=subset_size
    )

    # Split into train and validation
    dataset_size = len(full_dataset.all_image_paths)
    train_size = int(train_val_split * dataset_size)

    all_paths = full_dataset.all_image_paths.copy()
    random.shuffle(all_paths)

    train_paths = all_paths[:train_size]
    val_paths = all_paths[train_size:]

    # Create separate datasets
    train_dataset = TripletImageDataset(
        root_dir=data_dir, transform=transform,
        triplets_per_image=triplets_per_image, subset_size=None
    )
    train_dataset.all_image_paths = train_paths

    val_dataset = TripletImageDataset(
        root_dir=data_dir, transform=transform,
        triplets_per_image=triplets_per_image, subset_size=None
    )
    val_dataset.all_image_paths = val_paths

    # Create dataloaders
    train_loader = DataLoader(
        train_dataset, batch_size=batch_size, shuffle=True,
        num_workers=num_workers, pin_memory=True
    )

    val_loader = DataLoader(
        val_dataset, batch_size=batch_size, shuffle=False,
        num_workers=num_workers, pin_memory=True
    )

    print(f"\nDataLoaders created:")
    print(f"  Train: {len(train_dataset)} triplets ({len(train_paths)} images)")
    print(f"  Val: {len(val_dataset)} triplets ({len(val_paths)} images)")

    return train_loader, val_loader

print("✓ DataLoader functions defined")
# Out:
# ✓ DataLoader functions defined

# %% [markdown]
# ## Main Training Function

# %%
def train_complete_pipeline(data_dir: str, debug: bool = False):
    """Complete training pipeline with two-phase learning"""

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    print("="*60)
    print("CLIP Triplet Network Training")
    print("="*60)
    print(f"Device: {device}")
    print(f"Data directory: {data_dir}")
    print(f"Total epochs: {TOTAL_EPOCHS}")
    print(f"  Phase 1 (frozen CLIP): {PHASE1_EPOCHS} epochs")
    print(f"  Phase 2 (fine-tune): {PHASE2_EPOCHS} epochs")
    print("="*60)

    # Create dataloaders
    subset_size = 100 if debug else None

    train_loader, val_loader = create_dataloaders(
        data_dir=data_dir,
        batch_size=BATCH_SIZE,
        num_workers=NUM_WORKERS,
        train_val_split=TRAIN_VAL_SPLIT,
        clip_model_name=CLIP_MODEL_NAME,
        triplets_per_image=TRIPLETS_PER_IMAGE,
        subset_size=subset_size
    )

    # Create model
    model = CLIPTripletModel(
        clip_model_name=CLIP_MODEL_NAME,
        projection_dim=PROJECTION_DIM if USE_PROJECTION_HEAD else None,
        dropout=PROJECTION_DROPOUT,
        freeze_clip=True
    )

    # Print model info
    param_counts = model.count_parameters()
    print(f"\nModel parameters:")
    print(f"  Total: {param_counts['total']:,}")
    print(f"  Trainable: {param_counts['trainable']:,}")
    print(f"  Frozen: {param_counts['frozen']:,}")

    # Create trainer
    trainer = TripletTrainer(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        device=str(device),
        learning_rate=LEARNING_RATE,
        weight_decay=WEIGHT_DECAY,
        margin=TRIPLET_MARGIN
    )

    # ========== PHASE 1: Train projection head only ==========
    if PHASE1_EPOCHS > 0:
        print("\n" + "="*60)
        print("PHASE 1: Training projection head (CLIP frozen)")
        print("="*60)
        trainer.train(num_epochs=PHASE1_EPOCHS, phase=1)

    # ========== PHASE 2: Fine-tune CLIP + projection head ==========
    if PHASE2_EPOCHS > 0:
        print("\n" + "="*60)
        print("PHASE 2: Fine-tuning CLIP + projection head")
        print("="*60)

        # Unfreeze last N layers
        model.unfreeze_last_n_layers(UNFREEZE_LAST_N_LAYERS)

        # Recreate optimizer with lower LR
        trainer.optimizer = torch.optim.AdamW(
            model.parameters(),
            lr=LEARNING_RATE * 0.1,
            weight_decay=WEIGHT_DECAY
        )

        trainer.scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
            trainer.optimizer, T_max=PHASE2_EPOCHS, eta_min=1e-7
        )

        param_counts = model.count_parameters()
        print(f"Trainable parameters now: {param_counts['trainable']:,}")

        trainer.train(num_epochs=PHASE2_EPOCHS, phase=2)

    # Save final results
    print("\n" + "="*60)
    print("Training completed!")
    print("="*60)
    print(f"Best model saved at: {BEST_MODEL_PATH}")
    print(f"Last model saved at: {LAST_MODEL_PATH}")
    print(f"Best validation accuracy: {trainer.best_val_accuracy:.4f}")
    print(f"Best validation loss: {trainer.best_val_loss:.4f}")
    print("="*60)

    return trainer

print("✓ Main training function defined")
# Out:
# ✓ Main training function defined

# %% [markdown]
# ## Visualization Functions

# %%
def plot_training_history(trainer):
    """Plot training and validation metrics"""

    fig, axes = plt.subplots(1, 2, figsize=(15, 5))

    epochs = range(1, len(trainer.train_losses) + 1)

    # Plot losses
    axes[0].plot(epochs, trainer.train_losses, 'b-', label='Train Loss', linewidth=2)
    axes[0].plot(epochs, trainer.val_losses, 'r-', label='Val Loss', linewidth=2)
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('Loss', fontsize=12)
    axes[0].set_title('Training and Validation Loss', fontsize=14, fontweight='bold')
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)

    # Plot accuracies
    axes[1].plot(epochs, trainer.train_accuracies, 'b-', label='Train Accuracy', linewidth=2)
    axes[1].plot(epochs, trainer.val_accuracies, 'r-', label='Val Accuracy', linewidth=2)
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('Accuracy', fontsize=12)
    axes[1].set_title('Training and Validation Accuracy', fontsize=14, fontweight='bold')
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / 'training_history.png', dpi=150, bbox_inches='tight')
    plt.show()

    print(f"✓ Plot saved to {OUTPUT_DIR / 'training_history.png'}")

print("✓ Visualization functions defined")
# Out:
# ✓ Visualization functions defined

# %% [markdown]
# ## Run Training
#
# Execute the complete training pipeline

# %%
# Run training
# Set debug=True for a quick test run with small subset
trainer = train_complete_pipeline(data_dir=DATA_DIR, debug=False)
# Out:
# ============================================================
# CLIP Triplet Network Training
# ============================================================
# Device: cuda
# Data directory: /content/drive/MyDrive/raw-img/raw-img
# Total epochs: 15
#   Phase 1 (frozen CLIP): 10 epochs
#   Phase 2 (fine-tune): 5 epochs
# ============================================================
# 100%|███████████████████████████████████████| 338M/338M [00:11<00:00, 31.1MiB/s]
# Dataset: 10 classes, 26179 images
# Classes: butterfly, cat, chicken, cow, dog, elephant, horse, sheep, spider, squirrel
# Dataset: 10 classes, 26179 images
# Classes: butterfly, cat, chicken, cow, dog, elephant, horse, sheep, spider, squirrel
# Dataset: 10 classes, 26179 images
# Classes: butterfly, cat, chicken, cow, dog, elephant, horse, sheep, spider, squirrel
#
# DataLoaders created:
#   Train: 62829 triplets (20943 images)
#   Val: 15708 triplets (5236 images)
# Model: ViT-B/32, CLIP dim: 512, Output dim: 128
#
# Model parameters:
#   Total: 151,606,657
#   Trainable: 329,344
#   Frozen: 151,277,313
# Trainer initialized on cuda
#
# ============================================================
# PHASE 1: Training projection head (CLIP frozen)
# ============================================================
#
# ============================================================
# Phase 1 Training
# ============================================================
# Epoch 1 [Train]:   0%|          | 0/1964 [00:00<?, ?it/s]

# %% [markdown]
# ## Visualize Results

# %%
# Plot training history
plot_training_history(trainer)

# %% [markdown]
# ## Save Training Log

# %%
import pandas as pd

# Create training log DataFrame
training_log = pd.DataFrame({
    'Epoch': range(1, len(trainer.train_losses) + 1),
    'Train_Loss': trainer.train_losses,
    'Val_Loss': trainer.val_losses,
    'Train_Accuracy': trainer.train_accuracies,
    'Val_Accuracy': trainer.val_accuracies
})

# Save to CSV
training_log.to_csv(TRAINING_LOG, index=False)
print(f"✓ Training log saved to {TRAINING_LOG}")

# Display summary
print("\nTraining Summary:")
print(training_log.tail(10))

# %% [markdown]
# ## Download Model Checkpoints
#
# Download the trained model to your local machine

# %%
from google.colab import files

print("Downloading best model...")
files.download(str(BEST_MODEL_PATH))

print("Downloading last model...")
files.download(str(LAST_MODEL_PATH))

print("Downloading training log...")
files.download(str(TRAINING_LOG))

print(f"Model files location:")
print(f"  Best model: {BEST_MODEL_PATH}")
print(f"  Last model: {LAST_MODEL_PATH}")
print(f"  Training log: {TRAINING_LOG}")

# %% [markdown]
# ## Model Inference Example
#
# How to use the trained model for generating embeddings

# %%
# Load best model for inference
checkpoint = torch.load(BEST_MODEL_PATH, map_location='cpu')

# Create model and load weights
inference_model = CLIPTripletModel(
    clip_model_name=CLIP_MODEL_NAME,
    projection_dim=PROJECTION_DIM if USE_PROJECTION_HEAD else None,
    dropout=PROJECTION_DROPOUT,
    freeze_clip=False
)
inference_model.load_state_dict(checkpoint['model_state_dict'])
inference_model.eval()

print("✓ Model loaded for inference")
print(f"Best validation accuracy: {checkpoint['best_val_accuracy']:.4f}")

# Example: Generate embedding for a single image
def get_image_embedding(image_path: str, model, transform, device='cpu'):
    """Get embedding for a single image"""
    model = model.to(device)
    model.eval()

    # Load and transform image
    image = Image.open(image_path).convert('RGB')
    image_tensor = transform(image).unsqueeze(0).to(device)

    # Get embedding
    with torch.no_grad():
        embedding = model.encode_image(image_tensor)

    return embedding.cpu().numpy()

# Example usage (uncomment to test with your image)
# transform = get_clip_transforms(CLIP_MODEL_NAME)
# embedding = get_image_embedding('path/to/your/image.jpg', inference_model, transform)
# print(f"Embedding shape: {embedding.shape}")
# print(f"Embedding L2 norm: {np.linalg.norm(embedding):.4f}  (should be ~1.0)")

# %% [markdown]
# ## Final Summary
#
# ### What was trained:
# - CLIP-based triplet network for image similarity learning
# - Two-phase training: projection head → fine-tuning
# - Triplet loss with margin for metric learning
#
# ### Model outputs:
# - L2-normalized embeddings (dimension: 128)
# - Can be used for similarity search with cosine/euclidean distance
#
# ### Next steps:
# 1. Build FAISS index from all image embeddings
# 2. Implement similarity search
# 3. Visualize search results
#
# ### Files generated:
# - `best_triplet_model.pth` - Best model checkpoint
# - `last_triplet_model.pth` - Last epoch checkpoint
# - `training_log.csv` - Training metrics
# - `training_history.png` - Loss and accuracy plots
